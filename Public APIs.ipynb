# %%
import pandas as pd
import requests

# %% [markdown]
# # Last FM

# %% [markdown]
# https://www.last.fm/api/show/tag.getTopTracks

# %%
import getpass

apikey = getpass.getpass()
# Out:
# ········

# %%
base_url = "http://ws.audioscrobbler.com/2.0/"

# %%
toptracks_url = base_url + "?method=tag.gettoptracks&tag=disco&api_key=" + apikey + "&format=json"
    
toptracks_response = requests.get(toptracks_url)
toptracks_response.json()
# Out:
# {'tracks': {'track': [{'name': 'Billie Jean',
#     'duration': '293',
#     'mbid': 'f980fc14-e29b-481d-ad3a-5ed9b4ab6340',
#     'url': 'https://www.last.fm/music/Michael+Jackson/_/Billie+Jean',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'artist': {'name': 'Michael Jackson',
#      'mbid': 'f27ec8db-af05-4f36-916e-3d57f91ecf5e',
#      'url': 'https://www.last.fm/music/Michael+Jackson'},
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'}],
#     '@attr': {'rank': '1'}},
#    {'name': 'Dancing Queen',
# ...

# %%
# Extracting array on tracks from the original json

results_top10 = toptracks_response.json()

tracks = results_top10["tracks"]
track = tracks["track"]

# %%
from pandas.io.json import json_normalize

toptrack_results = pd.json_normalize(track)
toptrack_results
# Out:
#                                                 name duration  \
# 0                                        Billie Jean      293
# 1                                      Dancing Queen      352
# 2                                           Thriller      358
# 3                         The Less I Know the Better        0
# 4                                          September        0
# 5                                    I Want You Back      180
# 6                                 Can't Feel My Face        0
# 7                           Kiss Me More (feat. SZA)        0
# 8                                    Save Your Tears        0
# 9                                            Hung Up      336
# 10          Instant Crush (feat. Julian Casablancas)        0
# 11                         I Was Made for Lovin' You      282
# 12                                   doN'T StArT nOw        0
# 13                                         Mamma Mia      213
# ...

# %%
# Deleting some unwanted columns

toptrack_results = toptrack_results.drop(["mbid", "image", "streamable.#text", "streamable.fulltrack", "artist.mbid"], axis = 1)
toptrack_results.head()
# Out:
#                          name duration  \
# 0                 Billie Jean      293
# 1               Dancing Queen      352
# 2                    Thriller      358
# 3  The Less I Know the Better        0
# 4                   September        0
#
#                                                  url         artist.name  \
# 0  https://www.last.fm/music/Michael+Jackson/_/Bi...     Michael Jackson
# 1     https://www.last.fm/music/ABBA/_/Dancing+Queen                ABBA
# 2  https://www.last.fm/music/Michael+Jackson/_/Th...     Michael Jackson
# 3  https://www.last.fm/music/Tame+Impala/_/The+Le...         Tame Impala
# 4  https://www.last.fm/music/Earth,+Wind+&+Fire/_...  Earth, Wind & Fire
#
#                                      artist.url @attr.rank
# 0     https://www.last.fm/music/Michael+Jackson          1
# 1                https://www.last.fm/music/ABBA          2
# 2     https://www.last.fm/music/Michael+Jackson          3
# ...

# %% [markdown]
# # UK Bank Holidays

# %%
holiday_url = "https://www.gov.uk/bank-holidays.json"

holiday_response = requests.get(holiday_url)

holiday_json = holiday_response.json()
holiday_json
# Out:
# {'england-and-wales': {'division': 'england-and-wales',
#   'events': [{'title': 'New Year’s Day',
#     'date': '2018-01-01',
#     'notes': '',
#     'bunting': True},
#    {'title': 'Good Friday',
#     'date': '2018-03-30',
#     'notes': '',
#     'bunting': False},
#    {'title': 'Easter Monday',
#     'date': '2018-04-02',
#     'notes': '',
#     'bunting': True},
#    {'title': 'Early May bank holiday',
#     'date': '2018-05-07',
#     'notes': '',
#     'bunting': True},
#    {'title': 'Spring bank holiday',
#     'date': '2018-05-28',
#     'notes': '',
#     'bunting': True},
#    {'title': 'Summer bank holiday',
#     'date': '2018-08-27',
#     'notes': '',
#     'bunting': True},
#    {'title': 'Christmas Day',
#     'date': '2018-12-25',
#     'notes': '',
#     'bunting': True},
#    {'title': 'Boxing Day', 'date': '2018-12-26', 'notes': '', 'bunting': True},
#    {'title': 'New Year’s Day',
#     'date': '2019-01-01',
#     'notes': '',
#     'bunting': True},
# ...

# %%
records = holiday_json["england-and-wales"]
england_and_wales = records["events"]

england_and_wales_df = pd.json_normalize(england_and_wales)
england_and_wales_df["division"] = "england-and-wales"
england_and_wales_df
# Out:
#                      title        date notes  bunting           division
# 0           New Year’s Day  2018-01-01           True  england-and-wales
# 1              Good Friday  2018-03-30          False  england-and-wales
# 2            Easter Monday  2018-04-02           True  england-and-wales
# 3   Early May bank holiday  2018-05-07           True  england-and-wales
# 4      Spring bank holiday  2018-05-28           True  england-and-wales
# ..                     ...         ...   ...      ...                ...
# 62  Early May bank holiday  2025-05-05           True  england-and-wales
# 63     Spring bank holiday  2025-05-26           True  england-and-wales
# 64     Summer bank holiday  2025-08-25           True  england-and-wales
# 65           Christmas Day  2025-12-25           True  england-and-wales
# 66              Boxing Day  2025-12-26           True  england-and-wales
#
# [67 rows x 5 columns]

# %%
record1 = holiday_json["scotland"]
scotland = record1["events"]

scotland_df = pd.json_normalize(scotland)
scotland_df["division"] = "scotland"
scotland_df
# Out:
#                      title        date           notes  bunting  division
# 0           New Year’s Day  2018-01-01                     True  scotland
# 1              2nd January  2018-01-02                     True  scotland
# 2              Good Friday  2018-03-30                    False  scotland
# 3   Early May bank holiday  2018-05-07                     True  scotland
# 4      Spring bank holiday  2018-05-28                     True  scotland
# ..                     ...         ...             ...      ...       ...
# 70     Spring bank holiday  2025-05-26                     True  scotland
# 71     Summer bank holiday  2025-08-04                     True  scotland
# 72         St Andrew’s Day  2025-12-01  Substitute day     True  scotland
# 73           Christmas Day  2025-12-25                     True  scotland
# 74              Boxing Day  2025-12-26                     True  scotland
#
# [75 rows x 5 columns]

# %%
record1 = holiday_json["northern-ireland"]
northern_ireland = record1["events"]

northern_ireland_df = pd.json_normalize(northern_ireland)
northern_ireland_df["division"] = "northern-ireland"
northern_ireland_df
# Out:
#                                     title        date           notes  \
# 0                          New Year’s Day  2018-01-01
# 1                        St Patrick’s Day  2018-03-19  Substitute day
# 2                             Good Friday  2018-03-30
# 3                           Easter Monday  2018-04-02
# 4                  Early May bank holiday  2018-05-07
# ..                                    ...         ...             ...
# 78                    Spring bank holiday  2025-05-26
# 79  Battle of the Boyne (Orangemen’s Day)  2025-07-14  Substitute day
# 80                    Summer bank holiday  2025-08-25
# 81                          Christmas Day  2025-12-25
# 82                             Boxing Day  2025-12-26
#
#     bunting          division
# 0      True  northern-ireland
# 1      True  northern-ireland
# 2     False  northern-ireland
# 3      True  northern-ireland
# 4      True  northern-ireland
# ..      ...               ...
# 78     True  northern-ireland
# ...

# %%
holiday_df = pd.concat([england_and_wales_df, scotland_df ,northern_ireland_df], axis = 0)
holiday_df
# Out:
#                                     title        date           notes  \
# 0                          New Year’s Day  2018-01-01
# 1                             Good Friday  2018-03-30
# 2                           Easter Monday  2018-04-02
# 3                  Early May bank holiday  2018-05-07
# 4                     Spring bank holiday  2018-05-28
# ..                                    ...         ...             ...
# 78                    Spring bank holiday  2025-05-26
# 79  Battle of the Boyne (Orangemen’s Day)  2025-07-14  Substitute day
# 80                    Summer bank holiday  2025-08-25
# 81                          Christmas Day  2025-12-25
# 82                             Boxing Day  2025-12-26
#
#     bunting           division
# 0      True  england-and-wales
# 1     False  england-and-wales
# 2      True  england-and-wales
# 3      True  england-and-wales
# 4      True  england-and-wales
# ..      ...                ...
# 78     True   northern-ireland
# ...

# %% [markdown]
# # Emoji

# %%
emoji_url = "https://emojihub.yurace.pro/api/all"

response = requests.get(emoji_url)

results = response.json()

json_normalize(results)
# Out:
# /var/folders/yl/blp7v0ys1lzdfkls51wcv3l40000gn/T/ipykernel_15032/166404980.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   json_normalize(results)
#                                  name            category          group  \
# 0                       grinning face  smileys and people  face positive
# 1     grinning face with smiling eyes  smileys and people  face positive
# 2              face with tears of joy  smileys and people  face positive
# 3       rolling on the floor laughing  smileys and people  face positive
# 4        smiling face with open mouth  smileys and people  face positive
# ...                               ...                 ...            ...
# 1786                            yemen               flags          flags
# 1787                          mayotte               flags          flags
# 1788                     south africa               flags          flags
# ...

# %%
emoji_df = pd.DataFrame(results)
emoji_df
# Out:
#                                  name            category          group  \
# 0                       grinning face  smileys and people  face positive
# 1     grinning face with smiling eyes  smileys and people  face positive
# 2              face with tears of joy  smileys and people  face positive
# 3       rolling on the floor laughing  smileys and people  face positive
# 4        smiling face with open mouth  smileys and people  face positive
# ...                               ...                 ...            ...
# 1786                            yemen               flags          flags
# 1787                          mayotte               flags          flags
# 1788                     south africa               flags          flags
# 1789                           zambia               flags          flags
# 1790                         zimbabwe               flags          flags
#
#                     htmlCode             unicode
# ...
